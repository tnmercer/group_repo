# %%
import requests
import json

# %%
url = "https://global-market-data.p.rapidapi.com/etfs"

querystring = {"country":"united states"}

headers = {
	"X-RapidAPI-Key": "4118161e3amsh1443347b5c8b946p1281dajsn10cf8b98a14f",
	"X-RapidAPI-Host": "global-market-data.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response, indent=4))
# Out:
# [
#     {
#         "country": "united states",
#         "name": "AAM S&P 500 Sector High Dividend",
#         "full_name": "AAM S&P 500 Sector High Dividend",
#         "symbol": "SPDV",
#         "isin": "US26922A5948",
#         "asset_class": "equity",
#         "currency": "USD",
#         "stock_exchange": "NYSE",
#         "def_stock_exchange": true
#     },
#     {
#         "country": "united states",
#         "name": "AAM S&P EM Sector High Dividend",
#         "full_name": "AAM S&P Emerging Markets Sector High Dividend",
#         "symbol": "EEMD",
#         "isin": "US26922A5864",
#         "asset_class": "equity",
#         "currency": "USD",
#         "stock_exchange": "NYSE",
#         "def_stock_exchange": true
#     },
#     {
#         "country": "united states",
#         "name": "The Acquirers Fund",
#         "full_name": "The Acquirers Fund ETF",
#         "symbol": "ZIG",
#         "isin": "US26922A2630",
#         "asset_class": "equity",
# ...
